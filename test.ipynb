# %%
import pandas as pd
import matplotlib.pyplot as plt
cols = ['SPEED_A','TORQUE_A','P_OILOF']
read = pd.read_excel('VL.xlsx',usecols=cols,skiprows=[1],header=0)
#print(read)
read.plot('SPEED_A','P_OILOF')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
cols = ['SPEED_A','TORQUE_A','P_OILOF']
read = pd.read_excel('VL.xlsx',usecols=cols,skiprows=[1],header=0)
x=read.SPEED_A
y=read.TORQUE_A
z=read.P_OILOF
fig=plt.figure()
ax=Axes3D(fig)
ax.plot3D(x,y,z)
plt.show()

# %%
import pandas as pd
a = pd.read_excel('EA888_VL.xlsx',sheet_name=None,header=1,usecols=["SPEED_A","TORQUE_A","POWER"],skiprows=3)
keys =list(a.keys())
pd_con =pd.DataFrame()
print(a)
for i in keys:
    a = a[i]
    pd_con = pd.concat([pd,a],join='outer',  ignore_index=True)
    print(pd_con)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _handle_usecols(self, columns, usecols_key)
#    2826                         try:
# -> 2827                             col_indices.append(usecols_key.index(col))
#    2828                         except ValueError:
#
# ValueError: 'POWER' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-49806e8a012f> in <module>()
#       1 import pandas as pd
# ----> 2 a = pd.read_excel('EA888_VL.xlsx',sheet_name=None,header=1,usecols=["SPEED_A","TORQUE_A","POWER"],skiprows=3)
#       3 keys =list(a.keys())
#       4 pd_con =pd.DataFrame()
#       5 print(a)
#
# ...
